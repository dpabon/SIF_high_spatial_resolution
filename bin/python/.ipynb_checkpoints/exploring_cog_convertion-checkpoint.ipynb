# %%
import xarray as xr
import netCDF4
import matplotlib.pyplot as plt

# %%
org_files = xr.open_mfdataset('/Net/Groups/BGI/work_3/OEMC/oemc_sif/data/OEMC_app_data/Monitor_23_World-carbon_flux_monitor_netcdf/*.nc')

# %%
org_files
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 7200, lat: 3600, time: 539)
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.9 -179.9 -179.8 ... 179.9 179.9 180.0
#   * lat      (lat) float64 89.97 89.93 89.88 89.83 ... -89.88 -89.92 -89.97
#   * time     (time) datetime64[ns] 2007-01-21 2007-01-29 ... 2018-10-04
# Data variables:
#     SIF      (time, lat, lon) float32 dask.array<chunksize=(1, 3600, 7200), meta=np.ndarray>
#     crs      (time) |S1 b'' b'' b'' b'' b'' b'' b'' ... b'' b'' b'' b'' b'' b''
# Attributes: (12/24)
#     title:                     SIF
#     product_version:           2.0
#     Conventions:               CF-1.7
#     summary:                   Product generated using ’SIF spatially downsca...
#     keywords:                  sun-induced chlorophyll fluorescence
#     references:                Duveiller, G., & Cescatti, A. (2016). Spatiall...
#     ...                        ...
#     platform:                  MetOp
#     sensor:                    GOME-2
#     NCO:                       "4.5.4"
#     nco_openmp_thread_number:  1
#     history:                   Mon Aug 12 11:46:06 2019: ncatted -O -a tempor...
#     temporal_resolution:       Values every 8 days based on a 16-day moving w...

# %%
org_files['SIF'].sel(time = '2010-04-19').plot()

# %%
org_files['SIF'].sel(time = '2010-04-19', lat = slice(-10,10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 org_files['SIF'].sel(time = '2010-04-19', lat = slice(-10,10)).plot()
#
# File /Net/Groups/BGI/people/dpabon/miniconda3/envs/oemc_towers_env/lib/python3.11/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File /Net/Groups/BGI/people/dpabon/miniconda3/envs/oemc_towers_env/lib/python3.11/site-packages/xarray/plot/dataarray_plot.py:282, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     279 plotfunc: Callable
#     281 if ndims == 0 or darray.size == 0:
# --> 282     raise TypeError("No numeric data to plot.")
#     283 if ndims in (1, 2):
#     284     if row or col:
#
# TypeError: No numeric data to plot.

# %%
org_files['SIF'].sel(time = '2010-04-19').isel(lat = range(800,900), lon = range(0,3000)).plot()

# %%
org_files['SIF'].lat.plot()
